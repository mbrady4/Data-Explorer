# %%
from feature_explorer import data_dict

# %%
import pandas as pd

# %%
daily = pd.read_csv('daily.csv')

# %%
daily.head()
# Out:
#    Unnamed: 0   Total  PRCP  SNOW  SNWD  TMAX  TMIN  AWND  Total_yesterday
# 0  2012-10-04  3475.0     0     0     0   189    83    65           3521.0
# 1  2012-10-05  3148.0     0     0     0   217    89    57           3475.0
# 2  2012-10-06  2006.0     0     0     0   239    78    51           3148.0
# 3  2012-10-07  2142.0     0     0     0   239    78    13           2006.0
# 4  2012-10-08  3537.0     0     0     0   211    78    19           2142.0

# %%
data_dict(daily, daily['Total'])
# Out:
#                 Datatype  Unique Values  Null Values  Cardinality  \
# AWND               int64             76            0           76
# PRCP               int64             98            0           98
# SNOW               int64              6            0            6
# SNWD               int64              3            0            3
# TMAX               int64             65            0           65
# TMIN               int64             52            0           52
# Total            float64            942            0          942
# Total_yesterday  float64            942            0          942
# Unnamed: 0        object           1063            0         1063
#
#                 Correlation W/Target         Skew  Outlier Count  \
# AWND                      -0.0580965     -32.4998           16.0
# PRCP                      -0.0890183      3.57236            0.0
# SNOW                      0.00715107     -16.2322            0.0
# ...
